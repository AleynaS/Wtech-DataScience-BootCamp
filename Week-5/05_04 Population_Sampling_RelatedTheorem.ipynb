# %% [markdown]
# # <font color=blue>Assignments for "Main Statistical Concepts"</font>

# %% [markdown]
# Please upload your solutions to the following assignments as Jupyter Notebook to your GitHub account and share the GitHub link with the button below. You can talk to your mentor about your mind or ask Slack at office time.
#
# 1. In this assignment, you test whether the central limit theorem works. You generate 1000 variables with two normal distributions. You can determine the mean and standard deviation of these variables yourself. All you have to do is generate the first variable 50 times and averaged it each time. Generate the second variable 1000 times and averages this variable each time. Then plot the histogram of the averages of the two variables. Which of the variables has a mean distribution closer to the normal distribution? Do you think the Central Limit Theorem seems to have worked?

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
plt.figure(figsize=(8,5))

pop1 = np.random.normal(10, 0.5, 50)
pop2 = np.random.normal(10,0.5, 10000) 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
print("1. Mean of the sample: ", pop1.mean())
print("2. Mean of the sample : ", pop2.mean())
print("1. Standard deviation of sample: ", pop1.std())
print("2. Standard deviation of sample : ", pop2.std())
# Out:
# 1. Mean of the sample:  10.017605577906004
# 2. Mean of the sample :  9.99809012630216
# 1. Standard deviation of sample:  0.49402128784199906
# 2. Standard deviation of sample :  0.5010955805753469

# %%
sample = []
sample_means = []

for number_shots in np.random.normal(10, 0.5, 50):
    shot = np.random.randint(low=1,high=7, size=1)[0]
    sample.append(shot)
    sample_means.append(np.mean(sample))

# %%
print(sample[0:10])
print(sample_means[0:10])
# Out:
# [1, 3, 2, 1, 4, 1, 5, 4, 5, 4]
# [1.0, 2.0, 2.0, 1.75, 2.2, 2.0, 2.4285714285714284, 2.625, 2.888888888888889, 3.0]

# %%
def sample_plot(sample_means,sample_size, subplot_no):
    title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
    axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
    plt.subplot(subplot_no)
    plt.hlines(3.5, 0, sample_size, colors= 'r' )
    plt.plot(sample_means[0:sample_size])
    plt.ylim((1,6))
    plt.title("Sample Size = {}".format(sample_size), fontdict = title_font)
    plt.xlabel("Sample Size", fontdict = axis_font)
    plt.ylabel("Sample Mean", fontdict = axis_font)
    return plt

# %%
plt.figure(figsize=(15,3), dpi=100)
sample_plot(sample_means,50, 131) 
sample_plot(sample_means, 1000, 132)

plt.show()
