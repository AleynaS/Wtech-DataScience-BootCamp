# %% [markdown]
# # <font color=blue>Assignments for "Main Statistical Concepts"</font>

# %% [markdown]
# Please upload your solutions to the following assignments as Jupyter Notebook to your GitHub account and share the GitHub link with the button below. You can talk to your mentor about the issues you have in mind or ask Slack at office time.

# %% [markdown]
# 1. By using distribution=np.random.name_distribution([],[]), write the name of distribution of your choice in place of `name_distribution`and fill out the bracket with your choice again. Then please,
#
# a) Draw the histogram and interpret

# %%
import pandas as pd
import seaborn as sns
import numpy as np  
import math
from scipy.stats import norm
import matplotlib.pyplot as plt
sns.set()

binomial = np.random.binomial(10, 0.8, 100)
plt.hist(binomial)
plt.show()

# %% [markdown]
#    b) Draw Q-Q plot and interpret

# %%
from scipy import stats
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4), dpi = 150)
nsample = 100
res = stats.probplot(binomial, plot=plt)
plt.title("Q-Q Plot")
plt.xlabel("Theoretical Values")
plt.ylabel("Sample Data")
plt.show()

# %% [markdown]
# 2. Get the google stock quotes from 2015-2017 using https://finance.yahoo.com/. Using this data, calculate the stock return with the following formula:
#
# $$P_t-P_{t-1}/P_{t-1}$$
#
# where $P_t$ represents the stock price at time t and $P_{t-1}$ denotes the stock price at time t-1. What do you think about the return distribution?
#
# **Note:** Data is retrieved from https://finance.yahoo.com/ as follows. After clicking the given address, type the name of the stock you want to search in the search section (eg google). Click on the search result below to go to the relevant stock. When you get to the page with the relevant stock information, click the Historical Prices tab, select the relevant date range, then click Apply. Finally, click the Download Data button to download the data. Alternative you can use `yfinance` library

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (0.1.54)
# Requirement already satisfied: requests>=2.20 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: pandas>=0.24 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.0.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.18.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/melisademir/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.15.0)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
stock='AMZN'
start=datetime.datetime(2015,1,1)
end=datetime.datetime(2017,1,1)
amazon=yf.download(stock, start=start, end=end, interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
amazon.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31  311.549988  312.980011  310.010010  310.350006  310.350006
# 2015-01-02  312.579987  314.750000  306.959991  308.519989  308.519989
# 2015-01-05  307.010010  308.380005  300.850006  302.190002  302.190002
# 2015-01-06  302.239990  303.000000  292.380005  295.290009  295.290009
# 2015-01-07  297.500000  301.279999  295.329987  298.420013  298.420013
#
#              Volume
# Date
# 2014-12-31  2048000
# 2015-01-02  2783200
# 2015-01-05  2774200
# 2015-01-06  3519000
# 2015-01-07  2640300

# %%
pt_1=amazon[amazon.index==amazon.index[0]].Close
pt=amazon[amazon.index==amazon.index[-1]].Close
stock=(pt.values[0]-pt_1.values[0])/pt_1.values[0]

# %%
stock
# Out:
# 1.4162074444009267
